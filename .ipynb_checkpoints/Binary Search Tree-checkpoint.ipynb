# %%
class Node:
    def __init__(self, value, parent=None):
        self.value = value
        self.parent = parent
        self.left = None
        self.right = None

    def get(self, value):
        return self._get(value, self)

    def _get(self, value, node):
        if node is None or node.value is None:
            return None
        if value == node.value:
            return node
        if value < node.value:
            return self._get(value, node.left)
        return self._get(value, node.right)

    def insert(self, value):
        self._insert(value, self)

    def _insert(self, value, node):
        if node.value is None:
            node.value = value
        else:
            if value < node.value:
                if node.left is None:
                    node.left = Node(value, node)
                else:
                    self._insert(value, node.left)
            else:
                if node.right is None:
                    node.right = Node(value, node)
                else:
                    self._insert(value, node.right)

    def remove(self, value):
        self._remove(value, self)

    def _remove(self, value, root):
        node = root.get(value)
        if node is not None:
            if node.left is None and node.right is None:
                if value < node.parent.value:
                    node.parent.left = None
                else:
                    node.parent.right = None
            elif node.right is None:
                if value < node.parent.value:
                    node.parent.left = node.left
                else:
                    node.parent.right = node.left
            elif node.left is None:
                if value < node.parent.value:
                    node.parent.left = node.right
                else:
                    node.parent.right = node.right
            else:
                other_node = self._smallest(node.right)
                node.value = other_node.value
                self._remove(other_node.value, other_node)

    def _smallest(self, node):
        if node.left is None:
            return node
        return self._smallest(node.left)


bst = Node(5)
bst.insert(1)
bst.insert(9)
bst.insert(2)
bst.insert(7)
bst.insert(3)
bst.insert(4)
bst.insert(8)

bst.remove(5)

print(bst.get(7))
print(bst.get(4))
print(bst.get(5))
print(bst.get(3))
print(bst.value)
# Out:
# <__main__.Node object at 0x000002C0A4002F60>
# <__main__.Node object at 0x000002C0A40090F0>
# None
# <__main__.Node object at 0x000002C0A40090B8>
# 7
