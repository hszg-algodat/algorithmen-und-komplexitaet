# %% [markdown]
# # Asymptotische Aufwandsordnungen
#
# 1.
#     a)
#
#     $$
#     \begin{align*}
#     f_1(n) &= n^{0.999999} \log n \\
#     f_2(n) &= 10000000n \\
#     f_4(n) &= n^2 \\
#     f_3(n) &= 1.000001^n \\
#     \end{align*}
#     $$
#
#     b)
#
#     $$
#     \begin{align*}
#     f_1(n) &= 2^{2^{1000000}} \\
#     f_4(n) &= n \sqrt{n} \\
#     f_3(n) &= \binom{n}{2} \\
#     f_2(n) &= 2^{1000000n} \\
#     \end{align*}
#     $$
#
#     c)
#
#     $$
#     \begin{align*}
#     f_4(n) &= \sum_{i=1}^n (i + 1) \\
#     f_1(n) &= n^{\sqrt{n}} \\
#     f_3(n) &= n^{10} \cdot 2^{\frac{n}{2}} \\
#     f_2(n) &= 2^n \\
#     \end{align*}
#     $$
#
# 2.
#     a)
#     $\mathcal{O}(n)$
#
#     b)
#     $\mathcal{O}(n^2)$
#
#     c)
#     $\mathcal{O}(n \cdot m)$
#
#     d)
#     $\mathcal{O}(n)$
#
#     e)
#     $\mathcal{O}(n)$
#
#     f)
#     $\mathcal{O}(n)$
#
#     g)
#     $\mathcal{O}(\log n)$
#
#     h)
#     $\mathcal{O}(\log n)$
